# %% [markdown]
# # John's Travel Diary
#
# This post is to introduce you to John's favorite travel destination

# %%
name = input ("This is ")
# Out:
# This is John

# %% [markdown]
# ![john-cena.jpeg](attachment:john-cena.jpeg)

# %%
 pref1 = input("John fave sport")
# Out:
# John fave sport is swimming

# %%
pref2 = input("john loves ")
# Out:
# john loves the beach

# %%
pref3 = input("John's favourite place is ")
# Out:
# John's favourite place is Hawaii

# %% [markdown]
# This is a picture of John's *fave* beach in Hawaii
# ![beach.jpeg](attachment:beach.jpeg)
#
# <font color='red'> John's **top 3 things** to do in Hawaii are: </font>
# - Surfing
# - Swimming
# - Eating fish
#
# If you'd like to find out more about Hawaii please check out this <a href="https://youtu.be/su3ejcIeVdo"> video </a>
